# %%
import duckdb
import pandas as pd

# %%
# open connection to the database
con = duckdb.connect('/workspaces/practice/omop.db')

# %%
# show all tables in the database
con.execute('select * from information_schema.tables').fetchdf()
# Out:
#     table_catalog table_schema              table_name  table_type  \
# 0             NaN       synpuf           drug_exposure  BASE TABLE
# 1             NaN       synpuf              visit_cost  BASE TABLE
# 2             NaN       synpuf                specimen  BASE TABLE
# 3             NaN       synpuf                provider  BASE TABLE
# 4             NaN       synpuf    procedure_occurrence  BASE TABLE
# 5             NaN       synpuf          procedure_cost  BASE TABLE
# 6             NaN       synpuf                  person  BASE TABLE
# 7             NaN       synpuf    condition_occurrence  BASE TABLE
# 8             NaN       synpuf                   death  BASE TABLE
# 9             NaN       synpuf             device_cost  BASE TABLE
# 10            NaN       synpuf         device_exposure  BASE TABLE
# 11            NaN       synpuf               drug_cost  BASE TABLE
# 12            NaN       synpuf        visit_occurrence  BASE TABLE
# ...

# %%
con.execute('select * from synpuf.drug_exposure limit 5').fetchdf()
# Out:
#   drug_exposure_id person_id drug_concept_id drug_exposure_start_date  \
# 0         12773224    232691        40180096               2009-04-21
# 1         12773225    232691          904547               2009-07-08
# 2         12773226    232691        19018937               2009-04-27
# 3         12773227    232691          954692               2008-06-11
# 4         12773228    232691        19128367               2008-08-17
#
#   drug_exposure_end_date drug_type_concept_id stop_reason refills quantity  \
# 0                    NaN             38000175         NaN     NaN     30.0
# 1                    NaN             38000175         NaN     NaN     20.0
# 2                    NaN             38000175         NaN     NaN     30.0
# 3                    NaN             38000175         NaN     NaN      0.0
# 4                    NaN             38000175         NaN     NaN     20.0
#
#   days_supply  ... route_concept_id effective_drug_dose dose_unit_concept_id  \
# ...

# %%
con.execute('select * from synpuf.drug_cost limit 5').fetchdf()
# Out:
#   drug_cost_id drug_exposure_id currency_concept_id paid_copay  \
# 0     11120388         12773224            44818668        NaN
# 1     11120389         12773225            44818668        NaN
# 2     11120390         12773226            44818668        NaN
# 3     11120391         12773227            44818668        NaN
# 4     11120392         12773228            44818668        NaN
#
#   paid_coinsurance paid_toward_deductible paid_by_payer  \
# 0             0.00                    NaN           NaN
# 1            10.00                    NaN           NaN
# 2            10.00                    NaN           NaN
# 3            30.00                    NaN           NaN
# 4             0.00                    NaN           NaN
#
#   paid_by_coordination_of_benefits total_out_of_pocket total_paid  \
# 0                              NaN                0.00      30.00
# 1                              NaN               10.00      10.00
# ...

# %%
con.execute('select * from synpuf.device_exposure limit 5').fetchdf()
# Out:
#   device_exposure_id person_id device_concept_id device_exposure_start_date  \
# 0             526644    232691           2614833                 2008-03-07
# 1             526645    232691           2720870                 2010-09-10
# 2             526646    232691           2615309                 2010-09-10
# 3             526647    232691           2615045                 2008-08-23
# 4             526648    232692           2615663                 2009-05-10
#
#   device_exposure_end_date device_type_concept_id unique_device_id quantity  \
# 0               2008-03-07               44818705              NaN      NaN
# 1               2010-09-10               44818705              NaN      NaN
# 2               2010-09-10               44818705              NaN      NaN
# 3               2008-08-23               44818705              NaN      NaN
# 4               2009-05-10               44818705              NaN      NaN
#
# ...

# %%
con.execute('select * from synpuf.device_cost limit 5').fetchdf()
# Out:
#          column00            column01             column02    column03  \
# 0  device_cost_id  device_exposure_id  currency_concept_id  paid_copay
#
#            column04                column05       column06  \
# 0  paid_coinsurance  paid_toward_deductible  paid_by_payer
#
#                         column07             column08    column09  \
# 0  paid_by_coordination_benefits  total_out_of_pocket  total_paid
#
#                column10
# 0  payer_plan_period_id

# %%
con.execute('select * from synpuf.death limit 5').fetchdf()
# Out:
#   person_id  death_date death_type_concept_id cause_concept_id  \
# 0    232706  2010-08-01              38003565              NaN
# 1    232743  2009-02-01              38003565              NaN
# 2    232773  2009-06-01              38003565              NaN
# 3    232796  2008-02-01              38003565              NaN
# 4    232809  2010-10-01              38003565              NaN
#
#   cause_source_value cause_source_concept_id
# 0                NaN                       0
# 1                NaN                       0
# 2                NaN                       0
# 3                NaN                       0
# 4                NaN                       0

# %%
con.execute('select * from synpuf.condition_occurrence limit 5').fetchdf()
# Out:
#   condition_occurrence_id person_id condition_concept_id condition_start_date  \
# 0                30312801    232691                81902           2009-10-21
# 1                30312802    232691               374888           2009-10-21
# 2                30312803    232691                80180           2009-10-21
# 3                30312804    232691             44783163           2009-10-21
# 4                30312805    232691              4193704           2009-10-21
#
#   condition_end_date condition_type_concept_id stop_reason provider_id  \
# 0         2009-10-27                  38000200         NaN      126990
# 1         2009-10-27                  38000200         NaN      126990
# 2         2009-10-27                  38000200         NaN      126990
# 3         2009-10-27                  38000200         NaN      126990
# 4         2009-10-27                  38000200         NaN      126990
#
# ...

# %%
con.execute('select * from synpuf.care_site limit 5').fetchdf()
# Out:
#   care_site_id care_site_name place_of_service_concept_id location_id  \
# 0       268117            NaN                        8940         NaN
# 1       268118            NaN                        8940         NaN
# 2       268119            NaN                        8940         NaN
# 3       268120            NaN                        8940         NaN
# 4       268121            NaN                        8940         NaN
#
#   care_site_source_value place_of_service_source_value
# 0              143600703
# 1              214437080
# 2              236440380
# 3              839791796
# 4              754698403

# %%
con.execute('select * from synpuf.procedure_cost limit 5').fetchdf()
# Out:
#   procedure_cost_id procedure_occurrence_id currency_concept_id paid_copay  \
# 0          54840375                23151712            44818668        NaN
# 1          54840376                23151712            44818668        NaN
# 2          54840377                23151713            44818668        NaN
# 3          54840378                23151713            44818668        NaN
# 4          54840379                23151714            44818668        NaN
#
#   paid_coinsurance paid_toward_deductible paid_by_payer  \
# 0             0.00                  20.00         20.00
# 1            10.00                   0.00         40.00
# 2             0.00                  20.00         20.00
# 3            10.00                   0.00         40.00
# 4             0.00                  20.00         20.00
#
#   paid_by_coordination_benefits total_out_of_pocket total_paid  \
# 0                          0.00                20.0      20.00
# ...

# %%
con.execute('select * from synpuf.procedure_occurrence limit 5').fetchdf()
# Out:
#   procedure_occurrence_id person_id procedure_concept_id procedure_date  \
# 0                23151575    232691              2000858     2009-10-21
# 1                23151576    232691              4220195     2008-03-07
# 2                23151577    232691             40488932     2008-10-20
# 3                23151578    232691              2002562     2008-10-20
# 4                23151579    232691              2314290     2008-10-20
#
#   procedure_type_concept_id modifier_concept_id quantity provider_id  \
# 0                  38000251                 NaN      NaN      126990
# 1                  38000269                 NaN      NaN       22259
# 2                  38000269                 NaN      NaN       11975
# 3                  38000269                 NaN      NaN       11975
# 4                  38000269                 NaN      NaN       11975
#
#   visit_occurrence_id procedure_source_value procedure_source_concept_id  \
# ...

# %%
con.execute('select * from synpuf.provider limit 5').fetchdf()
# Out:
#   provider_id provider_name         NPI  DEA specialty_concept_id  \
# 0      730074           NaN  2703971976  NaN                  NaN
# 1      730075           NaN  5922348972  NaN                  NaN
# 2      730076           NaN  7004116054  NaN                  NaN
# 3      730077           NaN  8958565796  NaN                  NaN
# 4      730078           NaN  5946062843  NaN                  NaN
#
#   care_site_id year_of_birth gender_concept_id provider_source_value  \
# 0       268117           NaN               NaN            2703971976
# 1         5062           NaN               NaN            5922348972
# 2        13263           NaN               NaN            7004116054
# 3       198589           NaN               NaN            8958565796
# 4         8859           NaN               NaN            5946062843
#
#   specialty_source_value specialty_source_concept_id gender_source_value  \
# 0                    NaN                         NaN                 NaN
# ...

# %%
con.execute('select * from synpuf.specimen limit 5').fetchdf()
# Out:
#       column00   column01             column02                  column03  \
# 0  specimen_id  person_id  specimen_concept_id  specimen_type_concept_id
#
#         column04       column05  column06         column07  \
# 0  specimen_date  specimen_time  quantity  unit_concept_id
#
#                    column08                   column09            column10  \
# 0  anatomic_site_concept_id  disease_status_concept_id  specimen_source_id
#
#                 column11           column12                    column13  \
# 0  specimen_source_value  unit_source_value  anatomic_site_source_value
#
#                       column14
# 0  disease_status_source_value

# %%
con.execute('select * from synpuf.visit_cost limit 5').fetchdf()
# Out:
#         column00             column01             column02    column03  \
# 0  visit_cost_id  visit_occurrence_id  currency_concept_id  paid_copay
#
#            column04                column05       column06  \
# 0  paid_coinsurance  paid_toward_deductible  paid_by_payer
#
#                         column07             column08    column09  \
# 0  paid_by_coordination_benefits  total_out_of_pocket  total_paid
#
#                column10
# 0  payer_plan_period_id

# %%
# show first 5 rows in the visit_occurrence table
con.execute('select * from synpuf.visit_occurrence limit 5').fetchdf()
# Out:
#   visit_occurrence_id person_id visit_concept_id visit_start_date  \
# 0            11168677    232691             9201       2009-10-21
# 1            11168678    232691             9202       2008-03-07
# 2            11168679    232691             9202       2008-03-22
# 3            11168680    232691             9202       2008-10-20
# 4            11168681    232691             9202       2009-04-20
#
#   visit_start_time visit_end_date visit_end_time visit_type_concept_id  \
# 0              NaN     2009-10-27            NaN              44818517
# 1              NaN     2008-03-07            NaN              44818517
# 2              NaN     2008-03-22            NaN              44818517
# 3              NaN     2008-11-09            NaN              44818517
# 4              NaN     2009-05-10            NaN              44818517
#
#   provider_id care_site_id visit_source_value visit_source_concept_id
# 0      126990        10618    489431192399017                     NaN
# ...

# %%
# show first 5 row of the location table
con.execute('select * from synpuf.location limit 5').fetchdf()
# Out:
#   location_id address_1 address_2 city state  zip county location_source_value
# 0        3159       NaN       NaN  NaN    NE  NaN  28040                28-040
# 1        3160       NaN       NaN  NaN    KS  NaN  17970                17-970
# 2        3161       NaN       NaN  NaN    NE  NaN  28240                28-240
# 3        3162       NaN       NaN  NaN    AK  NaN  02160                02-160
# 4        3163       NaN       NaN  NaN    NE  NaN  28410                28-410

# %%
# show first 5 rows of the measurement_occurrence table
con.execute('select * from synpuf.measurement_occurrence limit 5').fetchdf()
# Out:
#   measurement_id person_id measurement_concept_id measurement_date  \
# 0        6988116    232691                4062636       2008-03-22
# 1        6988117    232691                4245261       2008-10-20
# 2        6988118    232691                4319466       2010-09-09
# 3        6988119    232691                4184637       2010-09-09
# 4        6988120    232691                4007831       2010-09-09
#
#   measurement_time measurement_type_concept_id operator_concept_id  \
# 0              NaN                    45754907                 NaN
# 1              NaN                    45754907                 NaN
# 2              NaN                    45754907                 NaN
# 3              NaN                    45754907                 NaN
# 4              NaN                    45754907                 NaN
#
#   value_as_number value_as_concept_id unit_concept_id range_low range_high  \
# 0             NaN                   0             NaN       NaN        NaN
# ...

# %%
# show first 5 rows of the observation_period table
con.execute('select * from synpuf.observation_period limit 5').fetchdf()
# Out:
#   observation_period_id person_id observation_period_start_date  \
# 0                209916    232691                      20080131
# 1                209917    232692                      20080224
# 2                209918    232693                      20080128
# 3                209919    232694                      20080202
# 4                209920    232696                      20080317
#
#   observation_period_end_date period_type_concept_id
# 0                    20100929               44814722
# 1                    20101108               44814722
# 2                    20101205               44814722
# 3                    20101111               44814722
# 4                    20100822               44814722

# %%
# show first 5 rows of the observation table
con.execute('select * from synpuf.observation limit 5').fetchdf()
# Out:
#   observation_id person_id observation_concept_id observation_date  \
# 0        3941183    232691                3661841       2009-10-21
# 1        3941184    232691               44784283       2008-03-22
# 2        3941185    232691                2314311       2008-10-20
# 3        3941186    232691                2314313       2008-10-20
# 4        3941187    232691                2314311       2010-03-11
#
#   observation_time observation_type_concept_id value_as_number  \
# 0              NaN                    38000282             NaN
# 1              NaN                    38000282             NaN
# 2              NaN                    38000282             NaN
# 3              NaN                    38000282             NaN
# 4              NaN                    38000282             NaN
#
#   value_as_string value_as_concept_id qualifier_concept_id unit_concept_id  \
# 0             NaN                   0                  NaN             NaN
# ...

# %%
# show first 5 rows of the payer_plan_period table
con.execute('select * from synpuf.payer_plan_period limit 5').fetchdf()
# Out:
#   payer_plan_period_id person_id payer_plan_period_start_date  \
# 0               779441    232691                   2008-01-01
# 1               779442    232691                   2008-01-01
# 2               779443    232691                   2008-01-01
# 3               779444    232691                   2008-01-01
# 4               779445    232692                   2008-01-01
#
#   payer_plan_period_end_date payer_source_value plan_source_value  \
# 0                 2010-12-31                NaN   Medicare Part A
# 1                 2010-12-31                NaN   Medicare Part B
# 2                 2010-12-31                NaN               HMO
# 3                 2010-12-31                NaN   Medicare Part D
# 4                 2010-12-31                NaN   Medicare Part A
#
#   family_source_value
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# show first 5 rows of the person table
con.execute('select * from synpuf.person limit 5').fetchdf()
# Out:
#   person_id gender_concept_id year_of_birth month_of_birth day_of_birth  \
# 0    232691              8532          1926             01           01
# 1    232692              8507          1921             12           01
# 2    232693              8532          1929             04           01
# 3    232694              8532          1941             05           01
# 4    232695              8532          1925             08           01
#
#   time_of_birth race_concept_id ethnicity_concept_id location_id provider_id  \
# 0           NaN               0             38003564         250         NaN
# 1           NaN            8527             38003564         723         NaN
# 2           NaN            8527             38003564         351         NaN
# 3           NaN            8516             38003564        1106         NaN
# 4           NaN            8527             38003564         407         NaN
#
#   care_site_id person_source_value gender_source_value  \
# ...

# %%
con.execute('select * from synpuf.metadata limit 5').fetchdf()
# Out:
#             timestamp                                            message
# 0 2023-02-13 06:01:36                                   CMS_ETL starting
# 1 2023-02-13 06:01:36  BASE_SYNPUF_INPUT_DIRECTORY     =/workspaces/d...
# 2 2023-02-13 06:01:36  BASE_OUTPUT_DIRECTORY           =/workspaces/d...
# 3 2023-02-13 06:01:36  BASE_ETL_CONTROL_DIRECTORY      =/workspaces/d...
# 4 2023-02-13 06:09:20  ----------------------------------------------...

# %%
con.close()
