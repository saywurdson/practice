# %%
import duckdb
import pandas as pd

# %%
# open connection to the database
con = duckdb.connect('/workspaces/practice/omop.db')

# %%
# number of rows in synpuf.person table
print(con.execute('select count(*) from synthea.person').fetchone())
print(con.execute('select count(*) from synpuf.person').fetchone())
# Out:
# (112066,)

# %%
# show all tables in the database
con.execute('select * from information_schema.tables').fetchdf()
# Out:
#    table_catalog table_schema              table_name  table_type  \
# 0           omop       synpuf           drug_exposure  BASE TABLE
# 1           omop       synpuf               drug_cost  BASE TABLE
# 2           omop       synpuf         device_exposure  BASE TABLE
# 3           omop       synpuf             device_cost  BASE TABLE
# 4           omop       synpuf                   death  BASE TABLE
# 5           omop       synpuf    condition_occurrence  BASE TABLE
# 6           omop       synpuf                  person  BASE TABLE
# 7           omop       synpuf       payer_plan_period  BASE TABLE
# 8           omop       synpuf             observation  BASE TABLE
# 9           omop       synpuf      observation_period  BASE TABLE
# 10          omop       synpuf  measurement_occurrence  BASE TABLE
# 11          omop       synpuf                location  BASE TABLE
# 12          omop       synpuf        visit_occurrence  BASE TABLE
# 13          omop       synpuf              visit_cost  BASE TABLE
# 14          omop       synpuf                specimen  BASE TABLE
# 15          omop       synpuf                provider  BASE TABLE
# 16          omop       synpuf    procedure_occurrence  BASE TABLE
# 17          omop       synpuf          procedure_cost  BASE TABLE
# 18          omop       synpuf               care_site  BASE TABLE
# 19          omop      synthea               care_site  BASE TABLE
# 20          omop      synthea             measurement  BASE TABLE
# 21          omop      synthea               personmap  BASE TABLE
# 22          omop      synthea                visitmap  BASE TABLE
# 23          omop      synthea        visit_occurrence  BASE TABLE
# 24          omop      synthea                provider  BASE TABLE
# 25          omop      synthea    procedure_occurrence  BASE TABLE
# 26          omop      synthea                  person  BASE TABLE
# 27          omop      synthea             observation  BASE TABLE
# 28          omop      synthea      observation_period  BASE TABLE
# 29          omop      synthea                location  BASE TABLE
# 30          omop      synthea           drug_exposure  BASE TABLE
# 31          omop      synthea                   death  BASE TABLE
# 32          omop      synthea    condition_occurrence  BASE TABLE
#
#     self_referencing_column_name  reference_generation  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                           NaN                   NaN
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                           NaN                   NaN
# 30                           NaN                   NaN
# 31                           NaN                   NaN
# 32                           NaN                   NaN
#
#     user_defined_type_catalog  user_defined_type_schema  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 11                        NaN                       NaN
# 12                        NaN                       NaN
# 13                        NaN                       NaN
# 14                        NaN                       NaN
# 15                        NaN                       NaN
# 16                        NaN                       NaN
# 17                        NaN                       NaN
# 18                        NaN                       NaN
# 19                        NaN                       NaN
# 20                        NaN                       NaN
# 21                        NaN                       NaN
# 22                        NaN                       NaN
# 23                        NaN                       NaN
# 24                        NaN                       NaN
# 25                        NaN                       NaN
# 26                        NaN                       NaN
# 27                        NaN                       NaN
# 28                        NaN                       NaN
# 29                        NaN                       NaN
# 30                        NaN                       NaN
# 31                        NaN                       NaN
# 32                        NaN                       NaN
#
#     user_defined_type_name is_insertable_into is_typed commit_action
# 0                      NaN                YES       NO           NaN
# 1                      NaN                YES       NO           NaN
# 2                      NaN                YES       NO           NaN
# 3                      NaN                YES       NO           NaN
# 4                      NaN                YES       NO           NaN
# 5                      NaN                YES       NO           NaN
# 6                      NaN                YES       NO           NaN
# 7                      NaN                YES       NO           NaN
# 8                      NaN                YES       NO           NaN
# 9                      NaN                YES       NO           NaN
# 10                     NaN                YES       NO           NaN
# 11                     NaN                YES       NO           NaN
# 12                     NaN                YES       NO           NaN
# 13                     NaN                YES       NO           NaN
# 14                     NaN                YES       NO           NaN
# 15                     NaN                YES       NO           NaN
# 16                     NaN                YES       NO           NaN
# 17                     NaN                YES       NO           NaN
# 18                     NaN                YES       NO           NaN
# 19                     NaN                YES       NO           NaN
# 20                     NaN                YES       NO           NaN
# 21                     NaN                YES       NO           NaN
# 22                     NaN                YES       NO           NaN
# 23                     NaN                YES       NO           NaN
# 24                     NaN                YES       NO           NaN
# 25                     NaN                YES       NO           NaN
# 26                     NaN                YES       NO           NaN
# 27                     NaN                YES       NO           NaN
# 28                     NaN                YES       NO           NaN
# 29                     NaN                YES       NO           NaN
# 30                     NaN                YES       NO           NaN
# 31                     NaN                YES       NO           NaN
# 32                     NaN                YES       NO           NaN

# %%
# select 5 random rows
con.execute('select * from synpuf.drug_exposure offset floor(random() * (select count(*) from synpuf.drug_exposure)) limit 5').fetchdf()
# Out:
#   drug_exposure_id person_id drug_concept_id drug_exposure_start_date  \
# 0        145358499   2649814          725180               2010-10-01
# 1        145358500   2649814        43011896               2010-01-22
# 2        145358501   2649814        19079658               2010-10-08
# 3        145358502   2649814        40163547               2009-11-30
# 4        145358503   2649814          997899               2010-02-20
#
#   drug_exposure_end_date drug_type_concept_id stop_reason refills quantity  \
# 0                    NaN             38000175         NaN     NaN     30.0
# 1                    NaN             38000175         NaN     NaN     30.0
# 2                    NaN             38000175         NaN     NaN     90.0
# 3                    NaN             38000175         NaN     NaN     60.0
# 4                    NaN             38000175         NaN     NaN     60.0
#
#   days_supply  ... route_concept_id effective_drug_dose dose_unit_concept_id  \
# 0          30  ...              NaN                 NaN                  NaN
# 1          30  ...              NaN                 NaN                  NaN
# 2          30  ...              NaN                 NaN                  NaN
# 3          90  ...              NaN                 NaN                  NaN
# 4          30  ...              NaN                 NaN                  NaN
#
#   lot_number provider_id visit_occurrence_id drug_source_value  \
# 0        NaN         NaN                 NaN       24236015802
# 1        NaN         NaN                 NaN       08290037003
# 2        NaN         NaN                 NaN       67544040560
# 3        NaN         NaN                 NaN       58016078756
# 4        NaN         NaN                 NaN       51655053024
#
#   drug_source_concept_id route_source_value dose_unit_source_value
# 0               44981216                NaN                    NaN
# 1               44962613                NaN                    NaN
# 2               44973304                NaN                    NaN
# 3               44987471                NaN                    NaN
# 4               45257411                NaN                    NaN
#
# [5 rows x 21 columns]

# %%
con.execute('select * from synthea.drug_exposure offset floor(random() * (select count(*) from synthea.drug_exposure)) limit 5').fetchdf()
# Out:
#    drug_exposure_id  person_id  drug_concept_id drug_exposure_start_date  \
# 0          72868244     833007                0               1997-03-09
# 1          72868245     832961                0               2018-01-17
# 2          72868246     833010                0               2002-02-17
# 3          72868247     833010                0               2002-02-17
# 4          72868248     832999                0               2022-07-17
#
#   drug_exposure_start_datetime drug_exposure_end_date  \
# 0                   1997-03-09             1998-03-15
# 1                   2018-01-17             2018-02-07
# 2                   2002-02-17             2003-02-23
# 3                   2002-02-17             2003-02-23
# 4                   2022-07-17             2022-11-13
#
#   drug_exposure_end_datetime verbatim_end_date  drug_type_concept_id  \
# 0                 1998-03-15        1998-03-15                581452
# 1                 2018-02-07        2018-02-07                581452
# 2                 2003-02-23        2003-02-23                581452
# 3                 2003-02-23        2003-02-23                581452
# 4                 2022-11-13        2022-11-13                581452
#
#   stop_reason  ...  sig  route_concept_id  lot_number provider_id  \
# 0         NaN  ...  NaN                 0           0         NaN
# 1         NaN  ...  NaN                 0           0         NaN
# 2         NaN  ...  NaN                 0           0         NaN
# 3         NaN  ...  NaN                 0           0         NaN
# 4         NaN  ...  NaN                 0           0         NaN
#
#    visit_occurrence_id  visit_detail_id drug_source_value  \
# 0             40478834                0         424393004
# 1             40478836                0         741062008
# 2             40478829                0         160903007
# 3             40478829                0          73595000
# 4             40478842                0         160903007
#
#    drug_source_concept_id  route_source_value  dose_unit_source_value
# 0               424393004                 NaN                     NaN
# 1               741062008                 NaN                     NaN
# 2               160903007                 NaN                     NaN
# 3                73595000                 NaN                     NaN
# 4               160903007                 NaN                     NaN
#
# [5 rows x 23 columns]

# %%
con.execute('select * from synpuf.drug_cost offset floor(random() * (select count(*) from synpuf.drug_cost)) limit 5').fetchdf()
# Out:
#   drug_cost_id drug_exposure_id currency_concept_id paid_copay  \
# 0     50362237         57876096            44818668        NaN
# 1     50362238         57876097            44818668        NaN
# 2     50362239         57876098            44818668        NaN
# 3     50362240         57876099            44818668        NaN
# 4     50362241         57876100            44818668        NaN
#
#   paid_coinsurance paid_toward_deductible paid_by_payer  \
# 0             0.00                    NaN           NaN
# 1             0.00                    NaN           NaN
# 2            10.00                    NaN           NaN
# 3            40.00                    NaN           NaN
# 4             0.00                    NaN           NaN
#
#   paid_by_coordination_of_benefits total_out_of_pocket total_paid  \
# 0                              NaN                0.00       0.00
# 1                              NaN                0.00      10.00
# 2                              NaN               10.00      10.00
# 3                              NaN               40.00     130.00
# 4                              NaN                0.00      20.00
#
#   ingredient_cost dispensing_fee average_wholesale_price payer_plan_period_id
# 0             NaN            NaN                     NaN                  NaN
# 1             NaN            NaN                     NaN                  NaN
# 2             NaN            NaN                     NaN                  NaN
# 3             NaN            NaN                     NaN                  NaN
# 4             NaN            NaN                     NaN                  NaN

# %%
con.execute('select * from synpuf.device_exposure offset floor(random() * (select count(*) from synpuf.device_exposure)) limit 5').fetchdf()
# Out:
#   device_exposure_id person_id device_concept_id device_exposure_start_date  \
# 0            3750742   1653985           2614939                 2008-10-02
# 1            3750743   1653985           2614939                 2008-10-02
# 2            3750744   1653985           2614933                 2008-10-02
# 3            3750745   1653986           2615870                 2008-10-28
# 4            3750746   1653987           2720522                 2008-06-15
#
#   device_exposure_end_date device_type_concept_id unique_device_id quantity  \
# 0               2008-10-22               44818705              NaN      NaN
# 1               2008-10-22               44818705              NaN      NaN
# 2               2008-10-22               44818705              NaN      NaN
# 3               2008-11-02               44818705              NaN      NaN
# 4               2008-06-15               44818705              NaN      NaN
#
#   provider_id visit_occurrence_id device_source_value device_source_concept_id
# 0        4034            79338614               A4629                  2614939
# 1        4034            79338614               A4629                  2614939
# 2        4034            79338614               A4623                  2614933
# 3      407199            79338727               C1894                  2615870
# 4      366978            79338785               P9016                  2720522

# %%
con.execute('select * from synpuf.device_cost offset floor(random() * (select count(*) from synpuf.device_cost)) limit 5').fetchdf()
# Out:
#          column00            column01             column02    column03  \
# 0  device_cost_id  device_exposure_id  currency_concept_id  paid_copay
#
#            column04                column05       column06  \
# 0  paid_coinsurance  paid_toward_deductible  paid_by_payer
#
#                         column07             column08    column09  \
# 0  paid_by_coordination_benefits  total_out_of_pocket  total_paid
#
#                column10
# 0  payer_plan_period_id

# %%
con.execute('select * from synpuf.death offset floor(random() * (select count(*) from synpuf.death)) limit 5').fetchdf()
# Out:
#   person_id  death_date death_type_concept_id cause_concept_id  \
# 0   1775532  2009-03-01              38003565              NaN
# 1   1775535  2008-05-01              38003565              NaN
# 2   1775541  2009-06-01              38003565              NaN
# 3   1775544  2008-02-01              38003565              NaN
# 4   1775585  2009-03-01              38003565              NaN
#
#   cause_source_value cause_source_concept_id
# 0                NaN                       0
# 1                NaN                       0
# 2                NaN                       0
# 3                NaN                       0
# 4                NaN                       0

# %%
con.execute('select * from synpuf.condition_occurrence offset floor(random() * (select count(*) from synpuf.condition_occurrence)) limit 5').fetchdf()
# Out:
#   condition_occurrence_id person_id condition_concept_id condition_start_date  \
# 0               126596875    972710             44784439           2009-07-15
# 1               126596876    972710             44784439           2009-07-15
# 2               126596877    972710             44784439           2009-07-15
# 3               126596878    972710             44784439           2009-07-15
# 4               126596879    972710             44784439           2009-07-15
#
#   condition_end_date condition_type_concept_id stop_reason provider_id  \
# 0         2009-07-15                  38000230         NaN      203986
# 1         2009-07-15                  38000230         NaN      203986
# 2         2009-07-15                  38000230         NaN      203986
# 3         2009-07-15                  38000230         NaN      203986
# 4         2009-07-15                  38000230         NaN      203986
#
#   visit_occurrence_id condition_source_value condition_source_concept_id
# 0            46643484                  40310                    44835922
# 1            46643484                  40310                    44835922
# 2            46643484                  40310                    44835922
# 3            46643484                  40310                    44835922
# 4            46643484                  40310                    44835922

# %%
con.execute('select * from synthea.condition_occurrence offset floor(random() * (select count(*) from synthea.condition_occurrence)) limit 5').fetchdf()
# Out:
#    condition_occurrence_id  person_id  condition_concept_id  \
# 0                 44764408     890085                     0
# 1                 44764409     890085                     0
# 2                 44764410     890085               4309238
# 3                 44764411     890085               4251306
# 4                 44764412     890085               4234597
#
#   condition_start_date condition_start_datetime condition_end_date  \
# 0           1977-06-29                      NaN                NaT
# 1           1977-06-29                      NaN         1978-07-05
# 2           1977-06-29                      NaN         1984-07-11
# 3           1977-06-29                      NaN         1978-07-05
# 4           1977-06-29                      NaN         1978-07-05
#
#   condition_end_datetime  condition_type_concept_id  stop_reason provider_id  \
# 0                    NaN                      32020            0         NaN
# 1                    NaN                      32020            0         NaN
# 2                    NaN                      32020            0         NaN
# 3                    NaN                      32020            0         NaN
# 4                    NaN                      32020            0         NaN
#
#    visit_occurrence_id  visit_detail_id  condition_source_value  \
# 0             52589670                0               224295006
# 1             52589670                0               160903007
# 2             52589670                0               422650009
# 3             52589670                0                73595000
# 4             52589670                0               361055000
#
#    condition_source_concept_id condition_status_source_value  \
# 0                    224295006                           NaN
# 1                    160903007                           NaN
# 2                    422650009                           NaN
# 3                     73595000                           NaN
# 4                    361055000                           NaN
#
#   condition_status_concept_id
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
con.execute('select * from synpuf.care_site offset floor(random() * (select count(*) from synpuf.care_site)) limit 5').fetchdf()
# Out:
#   column0 column1 column2 column3    column4 column5
# 0  317008     NaN    8940     NaN  951229611
# 1  317009     NaN    8940     NaN  151916996
# 2  317010     NaN    8940     NaN  883163767
# 3  317011     NaN    8940     NaN  052145453
# 4  317012     NaN    8940     NaN  386850416

# %%
con.execute('select * from synthea.care_site offset floor(random() * (select count(*) from synthea.care_site)) limit 5').fetchdf()
# Out:
#         column0         column1                      column2      column3  \
# 0  care_site_id  care_site_name  place_of_service_concept_id  location_id
#
#                   column4                        column5
# 0  care_site_source_value  place_of_service_source_value

# %%
con.execute('select * from synpuf.procedure_cost offset floor(random() * (select count(*) from synpuf.procedure_cost)) limit 5').fetchdf()
# Out:
#   procedure_cost_id procedure_occurrence_id currency_concept_id paid_copay  \
# 0         243696461               102862716            44818668        NaN
# 1         243696462               102862717            44818668        NaN
# 2         243696463               102862718            44818668        NaN
# 3         243696464               102862719            44818668        NaN
# 4         243696465               102862720            44818668        NaN
#
#   paid_coinsurance paid_toward_deductible paid_by_payer  \
# 0            10.00                   0.00         50.00
# 1             0.00                   0.00         10.00
# 2             0.00                   0.00         10.00
# 3            20.00                   0.00         90.00
# 4            20.00                   0.00         90.00
#
#   paid_by_coordination_benefits total_out_of_pocket total_paid  \
# 0                          0.00                10.0      50.00
# 1                          0.00                 0.0      10.00
# 2                          0.00                 0.0      10.00
# 3                          0.00                20.0       0.00
# 4                          0.00                20.0       0.00
#
#   revenue_code_concept_id payer_plan_period_id revenue_code_source_value
# 0                     NaN                  NaN                       NaN
# 1                     NaN                  NaN                       NaN
# 2                     NaN                  NaN                       NaN
# 3                     NaN                  NaN                       NaN
# 4                     NaN                  NaN                       NaN

# %%
con.execute('select * from synpuf.procedure_occurrence offset floor(random() * (select count(*) from synpuf.procedure_occurrence)) limit 5').fetchdf()
# Out:
#   procedure_occurrence_id person_id procedure_concept_id procedure_date  \
# 0               100736422   1013041              2002291     2008-01-27
# 1               100736423   1013041             40489386     2010-03-08
# 2               100736424   1013041              4233827     2010-03-08
# 3               100736425   1013041              2108115     2010-03-08
# 4               100736426   1013041              2108115     2010-03-08
#
#   procedure_type_concept_id modifier_concept_id quantity provider_id  \
# 0                  38000269                 NaN      NaN      145634
# 1                  38000269                 NaN      NaN      718932
# 2                  38000269                 NaN      NaN      718932
# 3                  38000269                 NaN      NaN      718932
# 4                  38000269                 NaN      NaN      718932
#
#   visit_occurrence_id procedure_source_value procedure_source_concept_id  \
# 0            48587605                   4019                     2002291
# 1            48587608                   2721                     2001197
# 2            48587608                   4011                     2002290
# 3            48587608                  36415                     2108115
# 4            48587608                  36415                     2108115
#
#   qualifier_source_value
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
con.execute('select * from synthea.procedure_occurrence offset floor(random() * (select count(*) from synthea.procedure_occurrence)) limit 5').fetchdf()
# Out:
#    procedure_occurrence_id  person_id  procedure_concept_id  \
# 0                127330864     867593                     0
# 1                127330865     867593                     0
# 2                127330866     867593                     0
# 3                127330867     867593                     0
# 4                127330868     867593                     0
#
#        procedure_date             procedure_datetime  \
# 0 1991-08-26 07:37:48  1991-08-26T07:37:48Z 00:00:00
# 1 1991-08-26 07:37:48  1991-08-26T07:37:48Z 00:00:00
# 2 1991-08-26 07:37:48  1991-08-26T07:37:48Z 00:00:00
# 3 1991-08-26 07:37:48  1991-08-26T07:37:48Z 00:00:00
# 4 1991-08-26 07:37:48  1991-08-26T07:37:48Z 00:00:00
#
#    procedure_type_concept_id  modifier_concept_id quantity provider_id  \
# 0                   38000275                    0      NaN         NaN
# 1                   38000275                    0      NaN         NaN
# 2                   38000275                    0      NaN         NaN
# 3                   38000275                    0      NaN         NaN
# 4                   38000275                    0      NaN         NaN
#
#    visit_occurrence_id  visit_detail_id  procedure_source_value  \
# 0             47959882                0                47758006
# 1             47959882                0                31676001
# 2             47959882                0               310861008
# 3             47959882                0               165829005
# 4             47959882                0               269828009
#
#    procedure_source_concept_id modifier_source_value
# 0                     47758006                   NaN
# 1                     31676001                   NaN
# 2                    310861008                   NaN
# 3                    165829005                   NaN
# 4                    269828009                   NaN

# %%
con.execute('select * from synpuf.provider offset floor(random() * (select count(*) from synpuf.provider)) limit 5').fetchdf()
# Out:
#   column00 column01    column02 column03 column04 column05 column06 column07  \
# 0   852142      NaN  9319728439      NaN      NaN     6536      NaN      NaN
# 1   852143      NaN  4997196851      NaN      NaN    35500      NaN      NaN
# 2   852144      NaN  0444041076      NaN      NaN    89846      NaN      NaN
# 3   852145      NaN  7144135211      NaN      NaN   115274      NaN      NaN
# 4   852146      NaN  1333016814      NaN      NaN   250891      NaN      NaN
#
#      column08 column09 column10 column11 column12
# 0  9319728439      NaN      NaN      NaN      NaN
# 1  4997196851      NaN      NaN      NaN      NaN
# 2  0444041076      NaN      NaN      NaN      NaN
# 3  7144135211      NaN      NaN      NaN      NaN
# 4  1333016814      NaN      NaN      NaN      NaN

# %%
con.execute('select * from synthea.provider offset floor(random() * (select count(*) from synthea.provider)) limit 5').fetchdf()
# Out:
#       column00       column01 column02 column03              column04  \
# 0  provider_id  provider_name      NPI      DEA  specialty_concept_id
#
#        column05       column06           column07               column08  \
# 0  care_site_id  year_of_birth  gender_concept_id  provider_source_value
#
#                  column09                     column10             column11  \
# 0  specialty_source_value  specialty_source_concept_id  gender_source_value
#
#                    column12
# 0  gender_source_concept_id

# %%
con.execute('select * from synpuf.specimen offset floor(random() * (select count(*) from synpuf.specimen)) limit 5').fetchdf()
# Out:
#       column00   column01             column02                  column03  \
# 0  specimen_id  person_id  specimen_concept_id  specimen_type_concept_id
# 1  specimen_id  person_id  specimen_concept_id  specimen_type_concept_id
#
#         column04       column05  column06         column07  \
# 0  specimen_date  specimen_time  quantity  unit_concept_id
# 1  specimen_date  specimen_time  quantity  unit_concept_id
#
#                    column08                   column09            column10  \
# 0  anatomic_site_concept_id  disease_status_concept_id  specimen_source_id
# 1  anatomic_site_concept_id  disease_status_concept_id  specimen_source_id
#
#                 column11           column12                    column13  \
# 0  specimen_source_value  unit_source_value  anatomic_site_source_value
# 1  specimen_source_value  unit_source_value  anatomic_site_source_value
#
#                       column14
# 0  disease_status_source_value
# 1  disease_status_source_value

# %%
con.execute('select * from synpuf.visit_cost offset floor(random() * (select count(*) from synpuf.visit_cost)) limit 5').fetchdf()
# Out:
#         column00             column01             column02    column03  \
# 0  visit_cost_id  visit_occurrence_id  currency_concept_id  paid_copay
#
#            column04                column05       column06  \
# 0  paid_coinsurance  paid_toward_deductible  paid_by_payer
#
#                         column07             column08    column09  \
# 0  paid_by_coordination_benefits  total_out_of_pocket  total_paid
#
#                column10
# 0  payer_plan_period_id

# %%
con.execute('select * from synpuf.visit_occurrence offset floor(random() * (select count(*) from synpuf.visit_occurrence)) limit 5').fetchdf()
# Out:
#   visit_occurrence_id person_id visit_concept_id visit_start_date  \
# 0            50262405   1047865                0       2010-02-04
# 1            50262406   1047865                0       2010-10-03
# 2            50262407   1047865                0       2008-11-15
# 3            50262408   1047865                0       2009-08-09
# 4            50262409   1047865                0       2008-06-26
#
#   visit_start_time visit_end_date visit_end_time visit_type_concept_id  \
# 0              NaN     2010-02-04            NaN              44818517
# 1              NaN     2010-10-03            NaN              44818517
# 2              NaN     2008-11-15            NaN              44818517
# 3              NaN     2009-08-09            NaN              44818517
# 4              NaN     2008-06-26            NaN              44818517
#
#   provider_id care_site_id visit_source_value visit_source_concept_id
# 0      453694       180857    985133324421529                     NaN
# 1       38833        22636    985143325254283                     NaN
# 2       10316         1911    985213323418288                     NaN
# 3      330761       138221    985213324743745                     NaN
# 4          87           65    985213324839982                     NaN

# %%
con.execute('select * from synthea.visit_occurrence offset floor(random() * (select count(*) from synthea.visit_occurrence)) limit 5').fetchdf()
# Out:
#    visit_occurrence_id  person_id  visit_concept_id    visit_start_date  \
# 0             43749168     848657              9202 1984-03-12 15:40:37
# 1             43749169     848660                 0 2019-08-20 12:05:01
# 2             43749170     848652              9202 2006-09-22 22:12:34
# 3             43749171     848656              9202 2001-12-18 18:49:40
# 4             43749172     848658              9203 1969-10-13 10:47:02
#
#   visit_start_datetime      visit_end_date visit_end_datetime  \
# 0                  NaN 1984-03-12 15:55:37                NaN
# 1                  NaN 2019-08-28 12:20:01                NaN
# 2                  NaN 2006-09-22 22:27:34                NaN
# 3                  NaN 2001-12-18 19:24:39                NaN
# 4                  NaN 1969-10-13 11:47:02                NaN
#
#    visit_type_concept_id provider_id care_site_id visit_source_value  \
# 0               44818517         NaN          NaN         ambulatory
# 1               44818517         NaN          NaN                snf
# 2               44818517         NaN          NaN         ambulatory
# 3               44818517         NaN          NaN           wellness
# 4               44818517         NaN          NaN          emergency
#
#   visit_source_concept_id admitting_source_concept_id admitting_source_value  \
# 0                     NaN                         NaN                    NaN
# 1                     NaN                         NaN                    NaN
# 2                     NaN                         NaN                    NaN
# 3                     NaN                         NaN                    NaN
# 4                     NaN                         NaN                    NaN
#
#   discharge_to_concept_id discharge_to_source_value  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   preceding_visit_occurrence_id
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
con.execute('select * from synpuf.location offset floor(random() * (select count(*) from synpuf.location)) limit 5').fetchdf()
# Out:
#   location_id address_1 address_2 city state  zip county location_source_value
# 0        1322       NaN       NaN  NaN    NY  NaN  33770                33-770
# 1        1323       NaN       NaN  NaN    IA  NaN  16220                16-220
# 2        1324       NaN       NaN  NaN    NC  NaN  34610                34-610
# 3        1325       NaN       NaN  NaN    IN  NaN  15610                15-610
# 4        1326       NaN       NaN  NaN    CA  NaN  05070                05-070

# %%
con.execute('select * from synthea.location offset floor(random() * (select count(*) from synthea.location)) limit 5').fetchdf()
# Out:
#    location_id                     address_1 address_2      city       state  \
# 0       897607     155 Anderson Rue Suite 47       NaN   Edmonds  Washington
# 1       897608    1062 Heaney Arcade Unit 63       NaN    Tacoma  Washington
# 2       897609         1001 Schneider Center       NaN   Tukwila  Washington
# 3       897610    964 Tillman Meadow Unit 82       NaN    Auburn  Washington
# 4       897611  165 Conn Throughway Suite 69       NaN  Parkland  Washington
#
#      zip            county                 location_source_value
# 0  98026  Snohomish County  2e41ae94-c657-f69b-af5d-9409a3d11c2b
# 1  98466     Pierce County  b49a6f86-91c8-c3aa-c952-7d7a88b0e7c3
# 2  98108       King County  5a3b34d2-8f0f-29a5-8b15-b7b9c8618938
# 3  98391       King County  3774fd18-cd16-3c3f-e31a-2dd7e27270ed
# 4  98446     Pierce County  01a10f68-dabd-4657-e3ba-36b81ed16936

# %%
con.execute('select * from synpuf.measurement_occurrence offset floor(random() * (select count(*) from synpuf.measurement_occurrence)) limit 5').fetchdf()
# Out:
#   measurement_id person_id measurement_concept_id measurement_date  \
# 0       41921980   1396983                4243005       2008-02-22
# 1       41921981   1396983                4015482       2008-02-22
# 2       41921982   1396983                4319466       2008-02-22
# 3       41921983   1396983                2213031       2008-02-22
# 4       41921984   1396983                4319466       2008-02-22
#
#   measurement_time measurement_type_concept_id operator_concept_id  \
# 0              NaN                    45754907                 NaN
# 1              NaN                    45754907                 NaN
# 2              NaN                    45754907                 NaN
# 3              NaN                    45754907                 NaN
# 4              NaN                    45754907                 NaN
#
#   value_as_number value_as_concept_id unit_concept_id range_low range_high  \
# 0             NaN                   0             NaN       NaN        NaN
# 1             NaN                   0             NaN       NaN        NaN
# 2             NaN                   0             NaN       NaN        NaN
# 3             NaN                   0             NaN       NaN        NaN
# 4             NaN                   0             NaN       NaN        NaN
#
#   provider_id visit_occurrence_id measurement_source_value  \
# 0      176528            67000402                    83735
# 1      176528            67000402                    85379
# 2      176528            67000402                    85025
# 3      176528            67000402                    87186
# 4      176528            67000402                    85025
#
#   measurement_source_concept_id unit_source_value value_source_value
# 0                       2212453               NaN                NaN
# 1                       2212699               NaN                NaN
# 2                       2212648               NaN                NaN
# 3                       2213031               NaN                NaN
# 4                       2212648               NaN                NaN

# %%
con.execute('select * from synpuf.observation_period offset floor(random() * (select count(*) from synpuf.observation_period)) limit 5').fetchdf()
# Out:
#   observation_period_id person_id observation_period_start_date  \
# 0               2354833   2611155                      20080104
# 1               2354834   2611156                      20080604
# 2               2354835   2611157                      20091102
# 3               2354836   2611158                      20080227
# 4               2354837   2611160                      20080114
#
#   observation_period_end_date period_type_concept_id
# 0                    20100604               44814722
# 1                    20101222               44814722
# 2                    20101028               44814722
# 3                    20101205               44814722
# 4                    20101213               44814722

# %%
con.execute('select * from synthea.observation_period offset floor(random() * (select count(*) from synthea.observation_period)) limit 5').fetchdf()
# Out:
#    observation_period_id  person_id observation_period_start_date  \
# 0               35263321     837125                    1953-12-24
# 1               35263322     837126                    1999-06-01
# 2               35263323     837127                    1959-05-03
# 3               35263324     837128                    1972-04-22
# 4               35263325     837129                    1958-03-14
#
#   observation_period_end_date  period_type_concept_id
# 0                  2022-04-08                44814724
# 1                  2022-05-02                44814724
# 2                  2022-11-15                44814724
# 3                  2022-04-30                44814724
# 4                  2023-01-27                44814724

# %%
con.execute('select * from synpuf.observation offset floor(random() * (select count(*) from synpuf.observation)) limit 5').fetchdf()
# Out:
#   observation_id person_id observation_concept_id observation_date  \
# 0       15371108    909091                1340204       2008-05-08
# 1       15371109    909091                1340204       2009-08-27
# 2       15371110    909091               46270007       2008-08-05
# 3       15371111    909091                1340204       2008-08-05
# 4       15371112    909091               46273937       2009-02-08
#
#   observation_time observation_type_concept_id value_as_number  \
# 0              NaN                    38000282             NaN
# 1              NaN                    38000282             NaN
# 2              NaN                    38000282             NaN
# 3              NaN                    38000282             NaN
# 4              NaN                    38000282             NaN
#
#   value_as_string value_as_concept_id qualifier_concept_id unit_concept_id  \
# 0             NaN                   0                  NaN             NaN
# 1             NaN                   0                  NaN             NaN
# 2             NaN                   0                  NaN             NaN
# 3             NaN                   0                  NaN             NaN
# 4             NaN                   0                  NaN             NaN
#
#   provider_id visit_occurrence_id observation_source_value  \
# 0       97454            43598339                     V454
# 1       97454            43598340                    V1359
# 2       97469            43598341                    V1741
# 3       97469            43598341                    V1254
# 4       97460            43598342                    V5861
#
#   observation_source_concept_id unit_source_value qualifier_source_value
# 0                      44835473               NaN                    NaN
# 1                      44827316               NaN                    NaN
# 2                      44827330               NaN                    NaN
# 3                      44827313               NaN                    NaN
# 4                      44831974               NaN                    NaN

# %%
con.execute('select * from synthea.observation offset floor(random() * (select count(*) from synthea.observation)) limit 5').fetchdf()
# Out:
#    observation_id  person_id  observation_concept_id observation_date  \
# 0        40674658     857510                       0       2006-12-29
# 1        40674659     857527                       0       1983-02-07
# 2        40674660     857274                 4053118       2011-05-02
# 3        40674661     857522                42538208       2017-10-25
# 4        40674662     857522                       0       2017-10-25
#
#   observation_datetime  observation_type_concept_id value_as_number  \
# 0           2006-12-29                     38000280             NaN
# 1           1983-02-07                     38000280             NaN
# 2           2011-05-02                     38000280             NaN
# 3           2017-10-25                     38000280             NaN
# 4           2017-10-25                     38000280             NaN
#
#   value_as_string  value_as_concept_id  qualifier_concept_id  unit_concept_id  \
# 0             NaN                    0                     0                0
# 1             NaN                    0                     0                0
# 2             NaN                    0                     0                0
# 3             NaN                    0                     0                0
# 4             NaN                    0                     0                0
#
#   provider_id  visit_occurrence_id  visit_detail_id  observation_source_value  \
# 0         NaN             46280698                0                  73595000
# 1         NaN             46280702                0                 283371005
# 2         NaN             46280699                0                 160903007
# 3         NaN             46280705                0                 741062008
# 4         NaN             46280705                0                 423315002
#
#    observation_source_concept_id unit_source_value qualifier_source_value
# 0                       73595000               NaN                    NaN
# 1                      283371005               NaN                    NaN
# 2                      160903007               NaN                    NaN
# 3                      741062008               NaN                    NaN
# 4                      423315002               NaN                    NaN

# %%
con.execute('select * from synpuf.payer_plan_period offset floor(random() * (select count(*) from synpuf.payer_plan_period)) limit 5').fetchdf()
# Out:
#   payer_plan_period_id person_id payer_plan_period_start_date  \
# 0              5349251   1598118                   2009-01-01
# 1              5349252   1598119                   2008-01-01
# 2              5349253   1598119                   2008-01-01
# 3              5349254   1598119                   2010-01-01
# 4              5349255   1598120                   2008-01-01
#
#   payer_plan_period_end_date payer_source_value plan_source_value  \
# 0                 2009-07-01                NaN   Medicare Part B
# 1                 2010-12-31                NaN   Medicare Part A
# 2                 2010-12-31                NaN   Medicare Part B
# 3                 2010-12-31                NaN   Medicare Part D
# 4                 2010-12-31                NaN   Medicare Part A
#
#   family_source_value
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
con.execute('select * from synpuf.person offset floor(random() * (select count(*) from synpuf.person)) limit 5').fetchdf()
# Out:
#   person_id gender_concept_id year_of_birth month_of_birth day_of_birth  \
# 0   2483020              8507          1949             10           01
# 1   2483021              8532          1967             08           01
# 2   2483022              8532          1943             10           01
# 3   2483023              8532          1943             10           01
# 4   2483024              8507          1940             12           01
#
#   time_of_birth race_concept_id ethnicity_concept_id location_id provider_id  \
# 0           NaN            8527             38003564         327         NaN
# 1           NaN            8527             38003564         709         NaN
# 2           NaN            8527             38003564        1436         NaN
# 3           NaN               0             38003564          46         NaN
# 4           NaN               0             38003563        2683         NaN
#
#   care_site_id person_source_value gender_source_value  \
# 0          NaN    5796F09AB13FA250                   1
# 1          NaN    5797FFC2317029AF                   2
# 2          NaN    579841E8F1EAC16D                   2
# 3          NaN    57988665C462A202                   2
# 4          NaN    579953B430F9094C                   1
#
#   gender_source_concept_id race_source_value race_source_concept_id  \
# 0                      NaN                 1                    NaN
# 1                      NaN                 1                    NaN
# 2                      NaN                 1                    NaN
# 3                      NaN                 3                    NaN
# 4                      NaN                 5                    NaN
#
#   ethnicity_source_value ethnicity_source_concept_id
# 0                      1                         NaN
# 1                      1                         NaN
# 2                      1                         NaN
# 3                      3                         NaN
# 4                      5                         NaN

# %%
con.execute('select * from synthea.person offset floor(random() * (select count(*) from synthea.person)) limit 5').fetchdf()
# Out:
#    person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0     860172               8507           1995              12             7
# 1     860173               8507           2018               6            28
# 2     860174               8507           1962              11            18
# 3     860175               8532           2002               5            24
# 4     860176               8532           1971               9            13
#
#   birth_datetime  race_concept_id  ethnicity_concept_id  location_id  \
# 0            NaN             8527                     0       860172
# 1            NaN             8527                     0       860173
# 2            NaN             8527                     0       860174
# 3            NaN             8527                     0       860175
# 4            NaN             8527                     0       860176
#
#   provider_id care_site_id                   person_source_value  \
# 0         NaN          NaN  c4a0d7b6-3583-d54e-4366-f3e4f408357f
# 1         NaN          NaN  f1233e62-bfcc-3990-eec4-54decfc6f32f
# 2         NaN          NaN  20a6c6a0-f21e-5d06-72cf-25b5243b36e6
# 3         NaN          NaN  14ea3326-fabd-cc2b-96a6-05af0a4ba933
# 4         NaN          NaN  c7cd35fc-c9dc-9b6f-8eaa-a2fa942d7958
#
#   gender_source_value  gender_source_concept_id race_source_value  \
# 0                   M                         0             white
# 1                   M                         0             white
# 2                   M                         0             white
# 3                   F                         0             white
# 4                   F                         0             white
#
#    race_source_concept_id ethnicity_source_value  ethnicity_source_concept_id
# 0                       0            nonhispanic                            0
# 1                       0            nonhispanic                            0
# 2                       0            nonhispanic                            0
# 3                       0               hispanic                            0
# 4                       0               hispanic                            0

# %%
con.close()
